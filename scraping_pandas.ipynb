# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Demography_of_Australia'

# %%
tables = pd.read_html(url)
tables
# Out:
# .24%
#  2           1808                     10263        +8.38%
#  3           1818                     25859        +9.68%
#  4           1828                     58197        +8.45%
#  5           1838                    151868       +10.07%
#  6           1848                    332328        +8.15%
#  7           1858                   1050828       +12.20%
#  8           1868                   1539552        +3.89%
#  9           1878                   2092164        +3.11%
#  10          1888                   2981677        +3.61%
#  11          1898                   3664715        +2.08%
#  12  Source: [50]              Source: [50]  Source: [50],
#                                                   Year  \
#  0                                                1901
#  1                                                1906
#  2                                                1911
#  3                                                1916
# ...

# %%
type(tables)
# Out:
# list

# %%
tables[17]
# Out:
#     Unnamed: 0 Average population  Live births  Deaths  Natural change  \
# 0         1900            3715000       102221   44060         58161.0
# 1         1901            3765000       102945   46330         56615.0
# 2         1902            3824000       102776   48078         54698.0
# 3         1903            3875000        98443   47293         51150.0
# 4         1904            3916000       104113   43572         60541.0
# ..         ...                ...          ...     ...             ...
# 115       2015           23858000       305377  159052        146325.0
# 116   2016[68]           24385600       311104  158504        152600.0
# 117       2017     24,770,700[69]       309142  160909        148233.0
# 118       2018     25,180,200[70]  315,147[71]  158493        156654.0
# 119       2019                NaN          NaN  169301             NaN
#
#      Crude birth rate (per 1,000)  Crude death rate (per 1,000)  \
# ...

# %%
tables[16]
# Out:
#                                 Years  1901  1911  1921  1951  1961  1971  \
# 0  Median age of the total population  22.5  24.0  25.8  30.3  29.3  27.7
# 1                 Median age of males  23.6  24.6  26.1  29.9  28.7  27.0
# 2               Median age of females  21.5  23.4  25.5  30.8  30.2  28.3
#
#    1981  1991  2001  2015  2017
# 0  29.6  32.4  35.7  37.4  38.7
# 1  29.0  31.7  34.9   NaN  37.9
# 2  30.2  33.0  36.4   NaN  39.5

# %%
tables[15]
# Out:
#                 Ages   1901  1911   1921   1931   1941   1951   1961   1971  \
# 0         0-14 years   35.1  31.6   31.8   28.5   24.2   27.2   30.3   28.7
# 1        15-24 years   19.4  20.1   16.9   18.1   17.5   14.1   14.3   17.4
# 2        25-44 years   29.4  28.8   30.0   29.3   30.0   29.4   27.7   27.4
# 3        45-64 years   12.0  14.8   17.0   18.0   20.9   20.4   19.9   20.0
# 4  65 years and over    4.0   4.3    4.5    6.1    7.4    8.1    8.5    8.3
# 5          Total (%)  100.0  99.6  100.0  100.0  100.0  100.0  100.0  100.0
#
#     1981   1991   2001   2007   2016
# 0   25.0   21.9   20.5   19.4   18.6
# 1   17.4   16.0   13.7   14.0   12.8
# 2   28.4   28.6   30.0   29.2   27.9
# 3   19.2   19.3   23.1   25.0   25.1
# 4    9.8   11.3   12.6   13.2   15.8
# 5  100.0  100.0  100.0  100.0  100.0

# %%
tables[4]
# Out:
#                 State/territory Population(2016 census) Land area          \
#                 State/territory Population(2016 census)       km²     mi²
# 0               New South Wales                 7797800    800642  309130
# 1                      Victoria                 6244200    227416   87806
# 2                    Queensland                 4883700   1730648  668207
# 3             Western Australia                 2567800   2239170  864548
# 4               South Australia                 1717000    983482  379725
# 5                      Tasmania                  519100     68401   26410
# 6  Australian Capital Territory                  406400      2358     910
# 7            Northern Territory                  245000   1349129  520902
#
#   Population density         % of populationin capital Notes
#              per km² per mi² % of populationin capital Notes
# 0               8.64    22.0                       63%  [40]
# ...

# %%
tables[3]
# Out:
#    Religion in Australia (2016)[24] Religion in Australia (2016)[24].1  \
# 0                          Religion                           Religion
# 1                       No religion                        No religion
# 2                    Roman Catholic                     Roman Catholic
# 3                   Other Christian                    Other Christian
# 4                          Anglican                           Anglican
# 5                             Islam                              Islam
# 6                          Buddhism                           Buddhism
# 7                          Hinduism                           Hinduism
# 8                           Sikhism                            Sikhism
# 9                           Judaism                            Judaism
# 10                            Other                              Other
# 11          Undefined or not stated            Undefined or not stated
#
# ...

# %%
tables[2]
# Out:
#    Source: Australian Bureau of Statistics (2019)[23]  \
#                                        Place of birth
# 0                               Total Australian-born
# 1                                  Total foreign-born
# 2                                          England[B]
# 3                                   Mainland China[C]
# 4                                               India
# 5                                         New Zealand
# 6                                         Philippines
# 7                                             Vietnam
# 8                                        South Africa
# 9                                               Italy
# 10                                           Malaysia
# 11                                          Sri Lanka
# 12                                        Scotland[D]
# 13                                              Nepal
# 14                                        South Korea
# ...

# %%
tables[1]
# Out:
#    vte Largest populated areas in Australia2019 data from Australian Bureau of Statistics[9]  \
#                                                                           Unnamed: 0_level_1
# 0                                     SydneyMelbourne
# 1                                     SydneyMelbourne
# 2                                     SydneyMelbourne
# 3                                     SydneyMelbourne
# 4                                     SydneyMelbourne
# 5                                     SydneyMelbourne
# 6                                     SydneyMelbourne
# 7                                     SydneyMelbourne
# 8                                     SydneyMelbourne
# 9                                     SydneyMelbourne
# 10                                    SydneyMelbourne
#
#                                                                       \
#              Rank                    Name    State       Pop. Rank.1
# ...
